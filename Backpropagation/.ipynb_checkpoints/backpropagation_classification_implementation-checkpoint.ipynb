# %%
#implementing backprop on classification problem
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[8,8,1],[7,9,1],[6,10,0],[5,5,0]], columns=['cgpa', 'profile_score', 'placed'])

# %%
df
# Out:
#    cgpa  profile_score  placed
# 0     8              8       1
# 1     7              9       1
# 2     6             10       0
# 3     5              5       0

# %%
def initialize(layer_dim):
  np.random.seed(3)
  parameters = {}
  L = len(layer_dim)

  for l in range(1,L):
    parameters['W'+str(l)] = np.ones((layer_dim[l-1], layer_dim[l]))*0.1
    parameters['b'+str(l)] = np.zeros((layer_dim[l],1))


  return parameters

# %%
def sigmoid(x):
  A = 1/(1+np.exp(-x))
  return A

# %%
def linear_prop(A_prev, W, b):
  Z = np.dot(W.T, A_prev) + b

  A = sigmoid(Z)

  return A

# %%
def L_linear_prop(X, parameters):
  A = X
  L = len(parameters) // 2                  # number of layers in the neural network

  for l in range(1, L+1):
    A_prev = A
    Wl = parameters['W' + str(l)]
    bl = parameters['b' + str(l)]
    #print("A"+str(l-1)+": ", A_prev)
    print("W"+str(l)+": ", Wl)
    #print("b"+str(l)+": ", bl)
    #print("--"*20)

    A = linear_prop(A_prev, Wl, bl)
    #print("A"+str(l)+": ", A)
    #print("**"*20)

  return A,A_prev

# %%
def update_parameters(parameters,y,y_hat,A1,X):
  parameters['W2'][0][0] = parameters['W2'][0][0] + (0.0001 * (y - y_hat)*A1[0][0])
  parameters['W2'][1][0] = parameters['W2'][1][0] + (0.0001 * (y - y_hat)*A1[1][0])
  parameters['b2'][0][0] = parameters['W2'][1][0] + (0.0001 * (y - y_hat))

  parameters['W1'][0][0] = parameters['W1'][0][0] + (0.0001 * (y - y_hat)*parameters['W2'][0][0]*A1[0][0]*(1-A1[0][0])*X[0][0])
  parameters['W1'][0][1] = parameters['W1'][0][1] + (0.0001 * (y - y_hat)*parameters['W2'][0][0]*A1[0][0]*(1-A1[0][0])*X[1][0])
  parameters['b1'][0][0] = parameters['b1'][0][0] + (0.0001 * (y - y_hat)*parameters['W2'][0][0]*A1[0][0]*(1-A1[0][0]))

  parameters['W1'][1][0] = parameters['W1'][1][0] + (0.0001 * (y - y_hat)*parameters['W2'][1][0]*A1[1][0]*(1-A1[1][0])*X[0][0])
  parameters['W1'][1][1] = parameters['W1'][1][1] + (0.0001 * (y - y_hat)*parameters['W2'][1][0]*A1[1][0]*(1-A1[1][0])*X[1][0])
  parameters['b1'][1][0] = parameters['b1'][1][0] + (0.0001 * (y - y_hat)*parameters['W2'][1][0]*A1[1][0]*(1-A1[1][0]))

# %%
parameters = initialize([2,2,1])
epochs = 20
for i in range(epochs):
  Loss = []
  X = df[['cgpa', 'profile_score']].values[0].reshape(2,1) # Shape(no of features, no. of training example)
  y = df[['placed']].values[0][0]

  # Parameter initialization
  parameters = initialize([2,2,1])

  y_hat,A1 = L_linear_prop(X,parameters)
  y_hat = y_hat[0][0]

  update_parameters(parameters,y,y_hat,A1,X)
  Loss.append(-y*np.log(y_hat) - (1-y)*np.log(1-y_hat))
  print('Loss for this student - ',-y*np.log(y_hat) - (1-y)*np.log(1-y_hat))

parameters
# Out:
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# W2:  [[0.1]
#  [0.1]]
# Loss for this student -  0.613402628898913
# {'W1': array([[0.10000513, 0.10000513],
#         [0.10000513, 0.10000513]]),
#  'b1': array([[6.41054186e-07],
#         [6.41054186e-07]]),
#  'W2': array([[0.10003815],
#         [0.10003815]]),
#  'b2': array([[0.100084]])}

# %%
# With keras
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(2,activation='sigmoid',input_dim=2))
model.add(Dense(1,activation='sigmoid'))

# %%
optimizer  = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy',optimizer=optimizer)

# %%
model.fit(df.iloc[:,0:-1].values,df['placed'].values,epochs=50,verbose=1,batch_size=1)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 1s 5ms/step - loss: 0.7429
# Epoch 2/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7417
# Epoch 3/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7414
# Epoch 4/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7406
# Epoch 5/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7404
# Epoch 6/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7396
# Epoch 7/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7398
# Epoch 8/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7386
# Epoch 9/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7380
# Epoch 10/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7374
# Epoch 11/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7369
# Epoch 12/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7364
# Epoch 13/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7358
# Epoch 14/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7353
# Epoch 15/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7345
# Epoch 16/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7343
# Epoch 17/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7337
# Epoch 18/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7333
# Epoch 19/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7329
# Epoch 20/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7322
# Epoch 21/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7310
# Epoch 22/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7306
# Epoch 23/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7300
# Epoch 24/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7295
# Epoch 25/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7294
# Epoch 26/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7285
# Epoch 27/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7281
# Epoch 28/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7274
# Epoch 29/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7267
# Epoch 30/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7264
# Epoch 31/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7251
# Epoch 32/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7246
# Epoch 33/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7244
# Epoch 34/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7239
# Epoch 35/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7227
# Epoch 36/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7221
# Epoch 37/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7217
# Epoch 38/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7215
# Epoch 39/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7199
# Epoch 40/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7196
# Epoch 41/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7189
# Epoch 42/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7183
# Epoch 43/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7179
# Epoch 44/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7163
# Epoch 45/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7163
# Epoch 46/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7157
# Epoch 47/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7142
# Epoch 48/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7135
# Epoch 49/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7135
# Epoch 50/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7123
